# %% [markdown]
# ### Test the RAG agent in batch mode
#
# This notebook shows how to use the agent to answer to a lsit of questions in batch.

# %%
from IPython.display import Image, display, Markdown

from agent_state import State
from rag_agent import create_workflow

from config import LLM_MODEL_ID

# %%
# agent configuration

agent_config = {
    "configurable": {
        "model_id": LLM_MODEL_ID,
        "enable_reranker": True,
        "enable_tracing": False,
        "main_language": "fr",
        "collection_name": "CNAF",
        "thread_id": "1234",
    }
}

# %%
# create the agent workflow
workflow = create_workflow()

# %%
#
# The list of questions
#
questions = [
    "Quel est l'objectif principal de l'Allocation Journalière du Proche Aidant (AJPA) ?",
    "Quelles sont les conditions de résidence requises pour l'aidant et la personne aidée ? ",
    "L'AJPA peut-elle être versée à un aidant rémunéré par la personne aidée, notamment par l'APA ou la PCH ?",
    "Quelle est la durée maximale en jours d'indemnisation AJPA sur l'ensemble de la carrière professionnelle de l'aidant ?",
    "L'AJPA est-elle cumulable avec l'indemnisation chômage sur l'intégralité d'un mois ?",
    "Quelles catégories professionnelles peuvent bénéficier de l'AJPA sans être nécessairement en Congé de Proche Aidant (CPA)?",
    "Quels documents un salarié (secteur privé ou public) doit-il fournir pour bénéficier de l'AJPA ?",
    "Comment est déterminé le montant journalier de l'AJPA pour une personne isolée ?",
    "Que devient le droit à l'AJPA en cas de décès de la personne aidée ?",
    "Quelles sont les incidences fiscales et sociales de l'AJPA (par exemple, imposition, CSG, CRDS et cumul avec d'autres prestations) ?"
]

# %%
#
# call in loop for each question
# final answer is streamed
#
for i, question in enumerate(questions):
    # input
    print("")
    print(f"Question {i+1}: {question}")
    print("")

    input_state = State(
        user_request=question,
        chat_history=[],
        error=None,
    )

    result = workflow.invoke(input_state, config=agent_config)

    # since the agent is streaming the generated answer
    # result["final_answer"] is a generator
    for chunk in result["final_answer"]:
        print(chunk.content, end="", flush=True)
    
    print("")
    print("")
    print("Citations:")
    print(result["citations"])
    
    # spacing for the next q/a
    print("")
    print("")
# Out:
# Question 1: Quel est l'objectif principal de l'Allocation Journalière du Proche Aidant (AJPA) ?
#
# ### Objectif principal de l'Allocation Journalière du Proche Aidant (AJPA)
#
# L'objectif principal de l'Allocation Journalière du Proche Aidant (AJPA) est d'indemniser la perte de revenu liée à la prise du congé de proche aidant. Cette allocation vise à soutenir les personnes qui doivent suspendre ou réduire leur activité professionnelle pour prendre en charge un proche présentant un handicap ou une perte d'autonomie d'une particulière gravité.
# Citations:
# [{'source': '1-Suivi_AJPA_docgen.pdf', 'page': '7'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '15'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '22'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '17'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '18'}]
#
#
#
# Question 2: Quelles sont les conditions de résidence requises pour l'aidant et la personne aidée ?
#
# ### Conditions de résidence pour l'aidant et la personne aidée
#
# Les conditions de résidence pour l'aidant et la personne aidée sont les suivantes :
#
# *   L'aidant doit résider en France de façon **stable et régulière**.
# *   La personne aidée doit également résider en France de façon **stable et régulière**, mais elle n'est pas obligée de résider avec l'aidant.
#
# Ces conditions sont importantes pour bénéficier de l'AJPA (Allocation Journalière de Presence pour Aidant).
# Citations:
# [{'source': '1-Suivi_AJPA_docgen.pdf', 'page': '9'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '14'}, {'source': "1-suivi_legislatif Prime d'Activité.pdf", 'page': '27'}]
#
#
#
# Question 3: L'AJPA peut-elle être versée à un aidant rémunéré par la personne aidée, notamment par l'APA ou la PCH ?
#
# ### Réponse
# Non, l'AJPA n'est pas due si l'aidant est rémunéré par la personne aidée, notamment par :
# * l'APA (allocation personnalisée d'autonomie)
# * la PCH (élément aide humaine)
# Citations:
# [{'source': '1-Suivi_AJPA_docgen.pdf', 'page': '22'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '21'}]
#
#
#
# Question 4: Quelle est la durée maximale en jours d'indemnisation AJPA sur l'ensemble de la carrière professionnelle de l'aidant ?
#
# La durée maximale en jours d'indemnisation AJPA sur l'ensemble de la carrière professionnelle de l'aidant est de **66 jours**.
# Citations:
# [{'source': '1-Suivi_AJPA_docgen.pdf', 'page': '17'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '15'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '7'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '12'}]
#
#
#
# Question 5: L'AJPA est-elle cumulable avec l'indemnisation chômage sur l'intégralité d'un mois ?
#
# ### Non, l'AJPA n'est pas cumulable avec l'indemnisation chômage sur l'intégralité d'un mois.
#
# Selon les informations fournies, si l’indemnisation chômage couvre la totalité du mois, il n'y a pas d'AJPA pour ce mois. Cependant, si l’indemnisation chômage ne couvre pas tout le mois, l’AJPA peut être valorisée pour les jours non couverts par l’indemnisation.
# Citations:
# [{'source': '1-Suivi_AJPA_docgen.pdf', 'page': '22'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '12'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '13'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '12'}]
#
#
#
# Question 6: Quelles catégories professionnelles peuvent bénéficier de l'AJPA sans être nécessairement en Congé de Proche Aidant (CPA)?
#
# Les catégories professionnelles suivantes peuvent bénéficier de l'AJPA sans être nécessairement en Congé de Proche Aidant (CPA) :
#
# * Les travailleurs indépendants
# * Les chômeurs indemnisés
# * Les stagiaires de la formation professionnelle
#
# Ces catégories peuvent percevoir l'AJPA pour compenser la perte de revenus liée à la prise en charge d'un proche en situation de handicap ou de perte d'autonomie, sans avoir à prendre un CPA.
# Citations:
# [{'source': '1-Suivi_AJPA_docgen.pdf', 'page': '7'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '22'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '10'}]
#
#
#
# Question 7: Quels documents un salarié (secteur privé ou public) doit-il fournir pour bénéficier de l'AJPA ?
#
# ### Documents nécessaires pour un salarié (secteur privé ou public) pour bénéficier de l'AJPA
#
# Un salarié du secteur privé ou public doit fournir les documents suivants pour bénéficier de l'AJPA :
#
# *   Demande d'AJPA
# *   Déclaration de situation (si besoin)
# *   Attestation mensuelle spécifique aux salariés, à faire compléter par l'employeur (attestation papier ou acquisition de l'information par moyens dématérialisés)
#
# Ces documents sont nécessaires pour justifier la suspension d'activité professionnelle et permettre le calcul de l'AJPA.
# Citations:
# [{'source': '1-Suivi_AJPA_docgen.pdf', 'page': '11'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '30'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '4'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '13'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '25'}]
#
#
#
# Question 8: Comment est déterminé le montant journalier de l'AJPA pour une personne isolée ?
#
# Le montant journalier de l'AJPA pour une personne isolée est déterminé comme suit :
# - Pour une journée entière, l'AJPA est de 13,467 % de la Bmaf, arrondi au centime d’euro le plus proche.
# - Pour une demi-journée, l'AJPA est de 6,734 % de la Bmaf, arrondi au centime d’euro le plus proche.
# Citations:
# [{'source': '1-Suivi_AJPA_docgen.pdf', 'page': '19'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '12'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '15'}]
#
#
#
# Question 9: Que devient le droit à l'AJPA en cas de décès de la personne aidée ?
#
# ### Droit à l'AJPA en cas de décès de la personne aidée
#
# Le document fourni ne spécifie pas explicitement ce qui arrive au droit à l'AJPA en cas de décès de la personne aidée. Il est donc impossible de donner une réponse précise basée sur les informations fournies.
#
# **Je ne connais pas la réponse à cette question.**
# Citations:
# [{'source': '1-Suivi_AJPA_docgen.pdf', 'page': '7'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '15'}]
#
#
#
# Question 10: Quelles sont les incidences fiscales et sociales de l'AJPA (par exemple, imposition, CSG, CRDS et cumul avec d'autres prestations) ?
#
# ### Incidences Fiscales et Sociales de l'AJPA
#
# L'AJPA (Allocation Journalière de Presence Accompagnante) a des implications à la fois sur le plan fiscal et social. Voici les détails :
#
# #### Implication Fiscale
#
# - **Imposition** : L'AJPA est imposable et soumise à prélèvement à la source. Le montant d’impôt prélevé à la source est calculé sur le montant brut de l'AJPA moins la CSG déductible.
# - **CSG et CRDS** : Les montants de l'AJPA sont soumis à la CSG (Contribution Sociale Généralisée) et à la CRDS (Contribution pour le Remboursement de la Dette Sociale), tant déductibles qu'indéductibles, sur le montant brut.
#
# #### Incidences Sociales
#
# - **Cumul avec d'autres prestations** : L'AJPA n'est pas cumulable avec certaines prestations, notamment l'AAH (Allocation Adulte Handicapé), la Prepare, le complément AEEH, la majoration de l'AEEH pour le même enfant, l'AJPP, et les indemnités de congé maternité, paternité, et d'adoption pour l'intégralité du mois.
# - **Exportabilité** : L'AJPA n'est pas exportable dans le cadre des règlements CEE et n'est donc pas prise en compte dans l'ADI (Allocation Différentielle d'Invalidité) ni dans le complément différentiel.
# - **Quotient Familial** : L'AJPA est prise en compte dans le calcul des divers quotients familiaux au titre des ressources annuelles, mais pas en tant que prestation.
# - **Affiliation à l'assurance vieillesse** : Les bénéficiaires de l'AJPA sont affiliés automatiquement à l'assurance vieillesse du régime général, sauf pour les fonctionnaires.
#
# #### Autres Considerations
#
# - **Contentieux** : Les contestations relatives à l'AJPA relèvent du contentieux général de la Sécurité sociale. Pour toute contestation sur le montant du PAS (Prélèvement à la Source) appliqué sur l'AJPA, les recours de l’allocataire sont à adresser à la DGFIP (Direction Générale des Finances Publiques).
#
# En résumé, l'AJPA a des implications significatives sur le plan fiscal et social, notamment en termes d'imposition, de CSG, de CRDS, et de cumul avec d'autres prestations. Il est essentiel de comprendre ces règles pour une gestion appropriée des ressources et des droits des bénéficiaires.
# Citations:
# [{'source': '1-Suivi_AJPA_docgen.pdf', 'page': '19'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '23'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '22'}, {'source': '1-Suivi_AJPA_docgen.pdf', 'page': '26'}]
